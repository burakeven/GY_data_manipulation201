# %% [markdown]
# # ELEMAN ISLEMLERI

# %%
import numpy as np

# %%
a = np.array([1,42,33,24,5])
a
# Out:
# array([ 1, 42, 33, 24,  5])

# %%
seri = pd.Series(a)

# %%
seri
# Out:
# 0     1
# 1    42
# 2    33
# 3    24
# 4     5
# dtype: int32

# %%
seri[0]
# Out:
# 1

# %%
seri[2:4]
# Out:
# 2    33
# 3    24
# dtype: int32

# %%
seri = pd.Series([12,54,64,123,54], index= ["reg","log","cart","lf","sa"])
seri
# Out:
# reg      12
# log      54
# cart     64
# lf      123
# sa       54
# dtype: int64

# %%
seri.index
# Out:
# Index(['reg', 'log', 'cart', 'lf', 'sa'], dtype='object')

# %%
seri.keys
# Out:
# <bound method Series.keys of reg      12
# log      54
# cart     64
# lf      123
# sa       54
# dtype: int64>

# %%
list(seri.items()) #her key degerine denk gelen degerleri gosterir.
# Out:
# [('reg', 12), ('log', 54), ('cart', 64), ('lf', 123), ('sa', 54)]

# %%
seri.values #degerlere ulasiriz
# Out:
# array([ 12,  54,  64, 123,  54], dtype=int64)

# %%
#eleman sorgulama

# %%
"reg" in seri #reg key'i bunun icinde mi? Sorusunun cevabini bize getirir.
# Out:
# True

# %%
"a" in seri
# Out:
# False

# %%
seri["reg"]
# Out:
# 12

# %%
#fancy eleman

# %%
seri[["lf","reg"]]
# Out:
# lf     123
# reg     12
# dtype: int64

# %%
seri["reg"] = 130

# %%
seri
# Out:
# reg     130
# log      54
# cart     64
# lf      123
# sa       54
# dtype: int64

# %%
seri["reg":"log"]
# Out:
# reg    130
# log     54
# dtype: int64
