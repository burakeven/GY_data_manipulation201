# %% [markdown]
# # Eleman Islemleri

# %%
import numpy as np
s1 = np.random.randint(10, size=5)
s2 = np.random.randint(10, size=5)
s3 = np.random.randint(10, size=5)

# %%
s1
# Out:
# array([1, 9, 6, 3, 8])

# %%
s2
# Out:
# array([0, 2, 1, 1, 8])

# %%
s3
# Out:
# array([1, 3, 8, 0, 7])

# %%
sozluk = {"var1": s1
         , "var2": s2
         , "var3": s3}

# %%
sozluk
# Out:
# {'var1': array([1, 9, 6, 3, 8]),
#  'var2': array([0, 2, 1, 1, 8]),
#  'var3': array([1, 3, 8, 0, 7])}

# %%
import pandas as pd
df = pd.DataFrame(sozluk)

# %%
df
# Out:
#    var1  var2  var3
# 0     1     0     1
# 1     9     2     3
# 2     6     1     8
# 3     3     1     0
# 4     8     8     7

# %%
df[0:1]
# Out:
#    var1  var2  var3
# 0     1     0     1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = ["a","b","c","d","e"]

# %%
df
# Out:
#    var1  var2  var3
# a     1     0     1
# b     9     2     3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
df["c":"e"]
# Out:
#    var1  var2  var3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
#silme

# %%
df.drop("a", axis=0)
# Out:
#    var1  var2  var3
# b     9     2     3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
df #goruldugu gibi ana dataframe'den silinmemis oldu.
# Out:
#    var1  var2  var3
# a     1     0     1
# b     9     2     3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
df.drop("a", axis=0, inplace= True) #inplace ile DataFrame üzerinde kalıcı degisiklik saglar. Axis kısmında 0 ile satiri belirtmis oluruz.
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-d26e791b86b6> in <module>
# ----> 1 df.drop("a", axis=0, inplace= True) #inplace ile DataFrame üzerinde kalıcı degisiklik saglar.
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df
# Out:
#    var1  var2  var3
# b     9     2     3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
#fancy

# %%
l = ["c","e"]

# %%
df.drop(l, axis= 0 )
# Out:
#    var1  var2  var3
# b     9     2     3
# d     3     1     0

# %%
#degiskenler icin

# %%
"var1" in df #var1 bu dataframe icerisinde var mi yok mu? Bunun cevabini getirir.
# Out:
# True

# %%
l = ["var1","var2","var4"]

# %%
for i in l:
    print(i in df) #indeks bazinda bir sorgulama yaparak bu degiskenlerin olup olmadigini for dongusu ile kontrol etmis olduk.
# Out:
# True
# True
# False

# %%
df
# Out:
#    var1  var2  var3
# b     9     2     3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
df["var4"] = df["var1"] * df["var2"]
df
# Out:
#    var1  var2  var3  var4
# b     9     2     3    18
# c     6     1     8     6
# d     3     1     0     3
# e     8     8     7    64

# %%
#degisken silmek

# %%
df.drop("var4", axis=1)
# Out:
#    var1  var2  var3
# b     9     2     3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
df
# Out:
#    var1  var2  var3  var4
# b     9     2     3    18
# c     6     1     8     6
# d     3     1     0     3
# e     8     8     7    64

# %%
df.drop("var4", axis=1, inplace = True)

# %%
df
# Out:
#    var1  var2  var3
# b     9     2     3
# c     6     1     8
# d     3     1     0
# e     8     8     7

# %%
l = ["var1", "var2"]

# %%
df.drop(l, axis=1)
# Out:
#    var3
# b     3
# c     8
# d     0
# e     7
